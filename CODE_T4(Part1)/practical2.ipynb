# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("student_performance.csv")

# %%
data.head()
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0          62             78             65               76     15-02-2018
# 1          65             80             68               78     10-05-2018
# 2          68             82             70               80     20-01-2019
# 3          70             85             72               82     18-03-2019
# 4          72             88             74               85     12-06-2019
#
#    Placement_Offer_Count
# 0                      1
# 1                      1
# 2                      2
# 3                      2
# 4                      3

# %%
print(data)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0           62             78             65               76     15-02-2018
# 1           65             80             68               78     10-05-2018
# 2           68             82             70               80     20-01-2019
# 3           70             85             72               82     18-03-2019
# 4           72             88             74               85     12-06-2019
# 5           75             90             76               88     25-09-2019
# 6           78             92             78               90     10-01-2020
# 7           80             95             80               92     14-03-2020
# 8           60             75             60               75     05-07-2018
# 9           63             77             62               77     19-10-2018
# 10          66             79             65               79     08-02-2019
# ...

# %%
data.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
data.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
df=pd.read_csv("student_performance.csv")
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0           62             78             65               76     15-02-2018
# 1           65             80             68               78     10-05-2018
# 2           68             82             70               80     20-01-2019
# 3           70             85             72               82     18-03-2019
# 4           72             88             74               85     12-06-2019
# 5           75             90             76               88     25-09-2019
# 6           78             92             78               90     10-01-2020
# 7           80             95             80               92     14-03-2020
# 8           60             75             60               75     05-07-2018
# 9           63             77             62               77     19-10-2018
# 10          66             79             65               79     08-02-2019
# ...

# %%
df.head()
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0          62             78             65               76     15-02-2018
# 1          65             80             68               78     10-05-2018
# 2          68             82             70               80     20-01-2019
# 3          70             85             72               82     18-03-2019
# 4          72             88             74               85     12-06-2019
#
#    Placement_Offer_Count
# 0                      1
# 1                      1
# 2                      2
# 3                      2
# 4                      3

# %%
df.tail()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 25          65             79             66               79     29-11-2018
# 26          68             82             69               82     16-05-2019
# 27          71             85             71               85     08-10-2019
# 28          75             88             74               87     30-01-2020
# 29          78             91             78               92     17-02-2021
#
#     Placement_Offer_Count
# 25                      1
# 26                      2
# 27                      3
# 28                      3
# 29                      5

# %%
df.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
df.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
df.dropna()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0           62             78             65               76     15-02-2018
# 1           65             80             68               78     10-05-2018
# 2           68             82             70               80     20-01-2019
# 3           70             85             72               82     18-03-2019
# 4           72             88             74               85     12-06-2019
# 5           75             90             76               88     25-09-2019
# 6           78             92             78               90     10-01-2020
# 7           80             95             80               92     14-03-2020
# 8           60             75             60               75     05-07-2018
# 9           63             77             62               77     19-10-2018
# 10          66             79             65               79     08-02-2019
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0           62             78             65               76     15-02-2018
# 1           65             80             68               78     10-05-2018
# 2           68             82             70               80     20-01-2019
# 3           70             85             72               82     18-03-2019
# 4           72             88             74               85     12-06-2019
# 5           75             90             76               88     25-09-2019
# 6           78             92             78               90     10-01-2020
# 7           80             95             80               92     14-03-2020
# 8           60             75             60               75     05-07-2018
# 9           63             77             62               77     19-10-2018
# 10          66             79             65               79     08-02-2019
# ...

# %%
df.dropna(thresh=3)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0           62             78             65               76     15-02-2018
# 1           65             80             68               78     10-05-2018
# 2           68             82             70               80     20-01-2019
# 3           70             85             72               82     18-03-2019
# 4           72             88             74               85     12-06-2019
# 5           75             90             76               88     25-09-2019
# 6           78             92             78               90     10-01-2020
# 7           80             95             80               92     14-03-2020
# 8           60             75             60               75     05-07-2018
# 9           63             77             62               77     19-10-2018
# 10          66             79             65               79     08-02-2019
# ...

# %%
df = df.bfill()

# %%
df = df.bfill()

# %%
df.replace(0, 100)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0           62             78             65               76     15-02-2018
# 1           65             80             68               78     10-05-2018
# 2           68             82             70               80     20-01-2019
# 3           70             85             72               82     18-03-2019
# 4           72             88             74               85     12-06-2019
# 5           75             90             76               88     25-09-2019
# 6           78             92             78               90     10-01-2020
# 7           80             95             80               92     14-03-2020
# 8           60             75             60               75     05-07-2018
# 9           63             77             62               77     19-10-2018
# 10          66             79             65               79     08-02-2019
# ...

# %%
df.replace(0, 1)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score Club_Join_Date  \
# 0           62             78             65               76     15-02-2018
# 1           65             80             68               78     10-05-2018
# 2           68             82             70               80     20-01-2019
# 3           70             85             72               82     18-03-2019
# 4           72             88             74               85     12-06-2019
# 5           75             90             76               88     25-09-2019
# 6           78             92             78               90     10-01-2020
# 7           80             95             80               92     14-03-2020
# 8           60             75             60               75     05-07-2018
# 9           63             77             62               77     19-10-2018
# 10          66             79             65               79     08-02-2019
# ...

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import boxplot


boxplot.col = ['MathScore', 'ReadingScore' , 'WritingScore','PlacementScore']

# %%
cols = ['MathScore', 'ReadingScore', 'WritingScore', 'PlacementScore']
print(df.columns)
plt.show()
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join_Date', 'Placement_Offer_Count'],
#       dtype='str')

# %%
print(np.where(df['Math_Score']>90))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['Reading_Score']<25))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['Writing_Score']<70))
# Out:
# (array([ 0,  1,  8,  9, 10, 11, 16, 17, 18, 19, 24, 25, 26]),)

# %%
plt.show()

# %%
cols = ['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score']
df.boxplot(cols)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,10))

# %%
ax.scatter(df['Placement_Score'], df['Writing_Score'])

# %%
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,10)) 
ax.scatter(df['Reading_Score'], df['Writing_Score'])

# %%
plt.show()
