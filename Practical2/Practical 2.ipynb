# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy import stats

# %%
#2. Load academic dataset
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72           72.0           74.0
# 1                 completed          69           90.0           88.0
# 2                      none          90            NaN           93.0
# 3                      none          47           57.0           44.0
# 4                      none          76           78.0            NaN
# ..                      ...         ...            ...            ...
# 995               completed          88           99.0           95.0
# 996                    none          62           55.0           55.0
# 997               completed          59           71.0           65.0
# 998               completed          68           78.0           77.0
# 999                    none          77           86.0           86.0
#
# [1000 rows x 8 columns]

# %%
df.columns
print(df.isnull().sum())
# Out:
# gender                         2
# race/ethnicity                 3
# parental level of education    2
# lunch                          0
# test preparation course        1
# math score                     0
# reading score                  5
# writing score                  1
# dtype: int64

# %%
# Fill missing numerical values with mean
df.fillna(df.mean(numeric_only=True), inplace=True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72      72.000000      74.000000
# 1                 completed          69      90.000000      88.000000
# 2                      none          90      69.138693      93.000000
# 3                      none          47      57.000000      44.000000
# 4                      none          76      78.000000      68.047047
# ..                      ...         ...            ...            ...
# 995               completed          88      99.000000      95.000000
# 996                    none          62      55.000000      55.000000
# 997               completed          59      71.000000      65.000000
# 998               completed          68      78.000000      77.000000
# 999                    none          77      86.000000      86.000000
#
# [1000 rows x 8 columns]

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Standardize column names
df.columns = df.columns.str.strip()

# %%
# 4. Describe dataset
print(df.head())
print(df.shape)
print(df.columns)
df.describe()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72      72.000000      74.000000
# 1               completed          69      90.000000      88.000000
# 2                    none          90      69.138693      93.000000
# 3                    none          47      57.000000      44.000000
# 4                    none          76      78.000000      68.047047
# (1000, 8)
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.138693      68.047047
# std      15.16308      14.569459      15.194066
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# 5. Identify outliers using IQR method

# Select numerical columns
numeric_cols = df.select_dtypes(include=[np.number])

# %%
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

# %%
outliers = ((numeric_cols < (Q1 - 1.5 * IQR)) |
            (numeric_cols > (Q3 + 1.5 * IQR)))

# %%
print("Outliers using IQR:")
print(outliers.sum())
# Out:
# Outliers using IQR:
# math score       8
# reading score    6
# writing score    5
# dtype: int64

# %%
# 6. Identify outliers using Z-score method

z_scores = np.abs(stats.zscore(numeric_cols))
print("Outliers using Z-score:")
print((z_scores > 3).sum(axis=0))
# Out:
# Outliers using Z-score:
# [4 4 4]

# %%
# 7. Apply data transformation

# Log transformation
df_log = numeric_cols.apply(lambda x: np.log1p(x))

# %%
# Normalization using Min-Max Scaling
scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(numeric_cols),
                             columns=numeric_cols.columns)

# %%
# 8. Display transformed data
print("Log Transformed Data:")
print(df_log.head())

print("Normalized Data:")
print(df_normalized.head())
# Out:
# Log Transformed Data:
#    math score  reading score  writing score
# 0    4.290459       4.290459       4.317488
# 1    4.248495       4.510860       4.488636
# 2    4.510860       4.250475       4.543295
# 3    3.871201       4.060443       3.806662
# 4    4.343805       4.369448       4.234788
# Normalized Data:
#    math score  reading score  writing score
# 0        0.72       0.662651       0.711111
# 1        0.69       0.879518       0.866667
# 2        0.90       0.628177       0.922222
# 3        0.47       0.481928       0.377778
# 4        0.76       0.734940       0.644967
